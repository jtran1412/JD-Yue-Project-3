# %%
# Import libraries

import pandas as pd
from random import random, seed

# %%
# set random seed
seed(42)

# %%
# Set sample size (0.25%)

SAMPLE_SIZE = 0.0025

# %%
# read and sample the CSV

df_downsized = pd.read_csv('yelp_academic_dataset_review.csv',
                 skiprows = lambda x: random() > SAMPLE_SIZE, header = None)

# %%
# Add headers to the dataframe

headers =  ["review_id", "user_id", "business_id", "stars", "useful", "funny", "cool", "text", "date"]
df_downsized.columns = headers

# %%
# Review the dataframe

df_downsized
# Out:
#                     review_id                 user_id             business_id  \
# 0      5Yy5ednS76755mL56QMbTg  L-lg41MG7tyfdacFEn286w  8LonS_bxNmCDk3FWiG9lzA
# 1      8YYXeVAhODVfZ5USShmD7w  ybrLqhrVUr5nwN0HNv2sYw  bj-_vwEXLa7ECiHZhoOmFg
# 2      aFOU4RlMNJDQkcf5KUEp5w  w6E_bt5Bk4mHvF5k6ICdDA  lsgslT1Ho5FsFLSeCJW3fw
# 3      yDQgyCdvWVBsBML98QerAw  mO8sN-ufvKuAbQ0vAYf1sw  yFrOuce72KhvW0LpU5FY6A
# 4      xZqWU7ozR38ziDe8qMWWBA  4QJLIvKJbyrxm9Dv3lf_TA  4WdDY97x4GdMYtyk1KQMnw
# ...                       ...                     ...                     ...
# 17404  GfkdjCXbSOTfRtp9BW7UYg  heSD8DBMNMW77Eqi31I9Xg  ozOneB4jXOD6hv5WBGj4KQ
# 17405  C8eVAR0jlxg58Dtuv4eRYA  mMK0ZqT4Y6wmu5tuwPYVxw  cFDP-1jlq2pa_BPjC-wd4g
# 17406  zYvOpBkUWW5q13awU0f9gA  Cj6dpCD9xmzZrsZ21ptG3w  -qttTkWNXN_6bQd1RrcYlQ
# 17407  Ouu9caoo3zZqSu9hk5U93A  TVQlI2_rQ5iTqmHvlp6q3g  cAAtoYUKC_Z8AmSF95mjcg
# 17408  -rzyH4Ltn2pmRgzDzUcEbA  AshBB8EMCttPOObB3ez6SQ  xkF7tAp85FdxnfobFNVJpg
#
# ...

# %%
# Get the descriptive statistics of the dataframe

df_downsized.describe()
# Out:
#               stars        useful         funny          cool
# count  17409.000000  17409.000000  17409.000000  17409.000000
# mean       3.757137      1.192429      0.334540      0.503935
# std        1.478538      2.744473      1.268966      1.897687
# min        1.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      0.000000      0.000000
# 75%        5.000000      1.000000      0.000000      0.000000
# max        5.000000     76.000000     33.000000     65.000000

# %%
# Convert the downsized datafrom to csv file for future use

df_downsized.to_csv('yelp.csv', index=False)
